# %% [markdown]
# ## Tuples

# %%
### Order in nature 
### Immutable
### Store elements like int , float , string, etc.
## Packing and unpacking (Study)

# %%
t = (1,2,3,4,5,6)
print(t)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
t = 1,2,3,4
print(t)
# Out:
# (1, 2, 3, 4)

# %%
t = 1,2,3,4
a,b,c,d = t
print(a)
print(b)
print(c)
print(d)
# Out:
# 1
# 2
# 3
# 4
