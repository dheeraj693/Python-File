# %% [markdown]
# ## Simple If Question

# %%
# 1.WAP to check if a number is positive.

n = int(input("Enter the number : "))
if n>0:
    print("Number is positive")

# %%
# 2.WAP to check if number is greater than 100.
n = int(input("Enter the number : "))
if n>100:
    print(f"{n} is greater than 100")

# %%
# 3.WAP to print message if a number is divisibale by 5.
n = int(input("Enter the number : "))
if n%5 == 0:
    print(f"{n} is divisible by 5")
# Out:
# Enter the number :  10
# 10 is divisible by 5

# %%
# 4.WAP to check eligible for vot (age>=18).
age = int(input("Enter the number : "))
if age>=18:
    print("A person is eligible for vote")
# Out:
# Enter the number :  19
# A person is eligible for vote

# %%
# 5.WAP to check even .
n = int(input("Enter the number : "))
if n % 2 == 0:
    print(f"{n} is a even nnumber")
# Out:
# Enter the number :  2
# 2 is a even nnumber

# %%
# 6.WAP to check number is multiple of 10
n = int(input("Enter the number : "))
if n % 10 == 0:
    print(f"{n} is multiple of 10")
# Out:
# Enter the number :  20
# 20 is multiple of 10

# %%
# 7.WAP to print greater than 90.
n = int(input("Enter the number : "))
if n>90:
    print(f"{n} is greater than 90")
# Out:
# Enter the number :  110
# 110 is greater than 90

# %%
# 8.WAP To check tempreture in above 30 degree.
temp = int(input("Enter the number : "))
if temp>30:
    print(f"{temp} degree temperature is above 30 degree")
# Out:
# Enter the number :  40
# 40 degree temperature is above 30 degree

# %%
# 9.WAP check salary is greater than 50,000.
salary = int(input("Enter the salary : "))
if salary > 50000:
    print(f"{salary} is more than 50,000")
# Out:
# Enter the salary :  333000
# 333000 is more than 50,000

# %%
# 10.WAP to check number is less than 0.
n = int(input("Enter the number : "))
if n<0:
    print(f"{n} is less than 0")
# Out:
# Enter the number :  -1
# -1 is less than 0

# %%
# 11.WAP check  exactly equal to 50
n = int(input("Enter the number : "))
if n==50:
    print(f"{n} is equal to 50")
# Out:
# Enter the number :  50
# 50 is equal to 50

# %%
# 12 . WAP to print Pass if marks greater than or equal to 40.
marks = int(input("Enter the marks : "))
if marks>=40:
    print("Pass")
# Out:
# Enter the marks :  47
# Pass

# %%
# 13.WAP to check year is greater than 2000.
year = int(input("Enter the number : "))
if year>2000:
    print(f"{year} is greater than 2000")
# Out:
# Enter the number :  2002
# 2002 is greater than 2000

# %%
# 14.WAP to print a massage if a number is divisible by 3
n = int(input("Enter the number : "))
if n % 3 == 0:
    print(f"{n} is a divisible by 3")
# Out:
# Enter the number :  13

# %%
# 15 Write a program to check if speed is above 80.
speed = int(input("Enter the speed"))
if speed > 80:
    print("Yes speed is above 80")
# Out:
# Enter the speed 90
# Yes speed is above 80

# %%
# 16 Write a program to print a message if weight is more than 70.
weight = int(input("Enter the weight : "))
if weight>70:
    print("Yes weight is more than 70")
# Out:
# Enter the weight :  80
# Yes weight is more than 70

# %%
# 17 Write a program to check if a number is between 1 and 10.
n = int(input("Enter the number : "))
if n>1 and n<10:
    print(f"Number {n} is between 1 and 10")
# Out:
# Enter the number :  3
# Number 3 is between 1 and 10

# %%
# 18 Write a program to print a message if bonus is greater than 5000.
bonus = int(input("Enter the bonus : "))
if bonus > 5000:
    print(f"Bonus {bonus} is greater than 5000")
# Out:
# Enter the bonus :  6000
# Bonus 6000 is greater than 5000

# %%
# 19 Write a program to check if score is equal to 0.
score = int(input("Enter the score : "))
if score == 0:
    print("Yes score in equal to 0")
# Out:
# Enter the score :  0
# Yes score in equal to 0

# %%
# 20 Write a program to print a message if experience is more than 2 years.
year = int(input("Enter the year : "))
if year > 2:
    print(f"Yes experience is more than 2 years")
# Out:
# Enter the year :  3
# Yes experience is more than 2 years

# %% [markdown]
# ## If else Question

# %%
# 1 Write a program to check whether a number is positive or negative.
n = int(input("Enter the number : "))
if n>0:
    print(f"{n} is positive number")
else:
    print(f"{n} is negative number")
# Out:
# Enter the number :  -1
# -1 is negative number

# %%
#2 Write a program to check whether a number is even or odd.
n = int(input("Enter the number : "))
if n % 2 == 0:
    print(f'{n} is even number')
else:
    print(f"{n} is odd number")
# Out:
# Enter the number :  3
# 3 is odd number

# %%
# 3 Write a program to check whether a person can vote or not.
age = int(input("Enter the age : "))
if age >= 18:
    print(f'Age {age} a person is eligible for vote ')
else:
    print(f"Age {age} a person in not eligible for vote")
# Out:
# Enter the age :  11
# Age 11 a person in not eligible for vote

# %%
# 4 Write a program to check whether a number is greater than 50 or not.
n = int(input("Enter the number : "))
if n  > 50:
    print(f'{n} is greater than 50')
else:
    print(f"{n} is not greater than 50")
# Out:
# Enter the number :  43
# 43 is not greater than 50

# %%
# 5 Write a program to check whether marks are pass or fail (pass ≥ 40).
marks = int(input("Enter the marks : "))
if marks >= 0:
    print(f'Marks {marks} Pass')
else:
    print(f"Marks {marks} fail")
# Out:
# Enter the marks :  21
# Marks 21 Pass

# %%
# 6 Write a program to check whether a number is divisible by 5 or not.
n = int(input("Enter the number : "))
if n%5 == 0:
    print(f"{n} is divisible by 5")
else:
    print(f"{n} is divisible by 5")
# Out:
# Enter the number :  65
# 65 is divisible by 5

# %%
#7 Write a program to check whether temperature is hot (>30) or normal.
temp = int(input("Enter the temperature : "))
if temp > 30:
    print("Hot weather")
else:
    print("Normal weather")
# Out:
# Enter the temperature :  32
# Hot weather

# %%
#8 Write a program to check whether salary is high (>60000) or low.
salary = int(input("Enter the salary : "))
if salary > 60000:
    print(f"Salary {salary} is  High")
else:
    print(f"Salary {salary} is Low ")
# Out:
# Enter the salary :  60001
# Salary 60001 is  High

# %%
#9 Write a program to check whether a number is a multiple of 7 or not.
n = int(input("Enter the number : "))
if n%7 == 0:
    print(f"{n} is multiple of 7")
else:
    print(f"{n} is not multiple of  7")
# Out:
# Enter the number :  70
# 70 is multiple of 7

# %%
# 10 Write a program to check whether speed is over limit (>80) or safe.
speed = int(input("Enter the speed : "))
if speed>80:
    print(f"{speed} speed is over limit")
else:
    print(f"{speed} speed is safe")
# Out:
# Enter the speed :  89
# 89 speed is over limit

# %%
# 11 Write a program to compare two numbers and print which one is greater.
n = int(input("Enter the value of n : "))
m = int(input("Enter the value of m : "))
if n>m:
    print(f"{n} is greater than {m}")
else:
    print(f"{m} is greater than {n}")
# Out:
# Enter the value of n :  40
# Enter the value of m :  54
# 54 is greater than 40

# %%
# 12 Write a program to check whether a number is zero or non-zero.
n = int(input("Enter the number : "))
if n == 0:
    print('Zero')
else:
    print("Non Zero")
# Out:
# Enter the number :  6
# Non Zero

# %%
# 13 Write a program to check whether a year is leap year or not.
year = int(input("Enter the year : "))
if (year%4==0 and year%100 != 0) or (year % 400 == 0):
    print(f'{year} is leap year')
else:
    print(f"{year} is not leap year")
# Out:
# Enter the year :  2000
# 2000 is leap year

# %%
# 14 Write a program to check whether marks are distinction (>75) or normal.
marks = int(input("Enter the marks : "))
if marks > 75:
    print(f'{marks} is distinction')
else:
    print(f"{marks} is normal")
# Out:
# Enter the marks :  76
# 76 is distinction

# %%
# 15 Write a program to check whether a number is less than 10 or greater/equal.
n = int(input("Enter the number : "))
if n>=10:
    print('Number is greater/equal to 10')
else:
    print("Less than 10")
# Out:
# Enter the number :  2
# Less than 10

# %%
# 16 Write a program to check whether bonus is given (>5000) or not.
bonus = int(input("Enter the bonus : "))
if bonus > 5000:
    print(f"Bonus {bonus} is greater than 5000")
else:
    print(f"Bonus {bonus} is less than 5000")
# Out:
# Enter the bonus :  50000
# Bonus 50000 is greater than 5000

# %%
# 17 Write a program to check whether a person is a minor (<18) or adult.
age = int(input("Enter the age : "))
if age >= 18:
    print(f'Age {age} a person is adult')
else:
    print(f"Age {age} a person is minor")
# Out:
# Enter the age :  12
# Age 12 a person is minor

# %%
# 18 Write a program to check whether a number is divisible by 2 or 3.

n = int(input("Enter the number : "))
if n % 3==0 and n%5 == 0:
    print(f"{n} is divisible by 3 and 5")
else:
    print(f"{n} is not divisible by 3 and 5")
# Out:
# Enter the number :  34
# 34 is not divisible by 3 and 5

# %%
#19 Write a program to check whether a number is greater than or equal to 100 or less.
n = int(input("Enter the number : "))
if n  >= 100:
    print(f'{n} is greater than or equal to 100')
else:
    print(f"{n} is less than 100")
# Out:
# Enter the number :  2
# 2 is less than 100

# %%
#20 Write a program to check whether a student is eligible for scholarship (>85) or not.

marks = int(input("Enter the marks : "))
if marks > 85:
    print(f'Marks {marks} student is eligible for scholarship')
else:
    print(f'Marks {marks} student is not eligible for scholarship')
# Out:
# Enter the marks :  122
# Marks 122 student is eligible for scholarship

# %%
#21 Write a program to check whether distance is long (>100 km) or short.
n = int(input("Enter the distance : "))
if n  > 100:
    print("Distance is long")
else:
    print("Distance is sort")
# Out:
# Enter the distance :  100
# Distance is sort

# %%
#22 Write a program to check whether weight is normal (<70) or high.
n = int(input("Enter the weight  : "))
if n  < 70:
    print("Weight is Normal")
else:
    print("Weight is High")
# Out:
# Enter the weight  :  70
# Weight is High

# %%
#23 Write a program to check whether score is above average (>50) or below.
n = int(input("Enter the Score  : "))
if n > 50:
    print("Score is above average")
else:
    print("Score is Below the average")
# Out:
# Enter the Score  :  32
# Score is Below the average

# %%
#24 Write a program to check whether working hours are overtime (>8) or normal.
n = int(input("Enter the hours  : "))
if n > 8:
    print("Working hour are overtime")
else:
    print("Working Hour are normal")
# Out:
# Enter the hours  :  5
# Working Hour are normal

# %%
# 25 Write a program to check whether a number is divisible by 10 or not.
n = int(input("Enter the number : "))
if n%10 == 0:
    print(f"{n} is divisible by 10")
else:
    print(f"{n} is divisible by 10")
# Out:
# Enter the number :  23
# 23 is divisible by 10

# %%
# 26 Write a program to check whether profit is made (>0) or loss.
n = int(input("Enter the profit  : "))
if n > 0:
    print("Yes Profit is made")
else:
    print("Loss")
# Out:
# Enter the profit  :  2
# Yes Profit is made

# %%
# 27 Write a program to check whether age is senior citizen (>60) or not.
age = int(input("Enter the age : "))
if age > 60:
    print(f'Age {age} is senior citizen')
else:
    print(f"Age {age} is not senior citizen")
# Out:
# Enter the age :  33
# Age 33 is not senior citizen

# %%
#28 Write a program to check whether a number is square of 5 (=25) or not.
n = int(input("Enter the number : "))
if n == 25:
    print(f"{n} is square of 5 ")
else:
    print(f"{n} is not square of 5 ")
# Out:
# Enter the number :  32
# 32 is not square of 5

# %%
# 29 Write a program to check whether rating is good (>4) or average.
n = int(input("Enter the Rating : "))
if n > 4:
    print(f"{n} is good rating")
else:
    print(f"{n} is average rating ")
# Out:
# Enter the Rating :  2
# 2 is average rating

# %%
#30 Write a program to check whether a number is greater than both 20 and 30 or not.
n = int(input("Enter the number : "))
if n >20 or n>3:
    print(f"{n} is square of 5 ")
else:
    print(f"{n} is not square of 5 ")
