# %% [markdown]
# ## String Slicing Question

# %%
#1. Take a string and print its first character using slicing.

s = 'Hello Python'
print(s[0])
# Out:
# H

# %%
#2. Take a string and print its last character using slicing.

s = 'Hello Python'
print(s[-1])
# Out:
# n

# %%
#3. Given a string, print the first two characters using slicing.
s = 'Hello Python'
print(s[0:2])
# Out:
# He

# %%
#4. Given a string, print the first three characters using slicing.

s = 'Hello Python'
print(s[0:3])
# Out:
# Hel

# %%
#5. Given a string, print the last two characters using slicing.

s = 'Hello Python'
print(s[-2:])
# Out:
# on

# %%
#6. Given a string, print the last three characters using slicing.
s = 'Hello Python'
print(s[-3:])
# Out:
# hon

# %%
#7. Take a string and print all characters except the first one using slicing.

s = 'Hello Python'
print(s[1:])
# Out:
# ello Python

# %%
#8. Take a string and print all characters except the last one using slicing.
s = 'Hello Python'
print(len(s))
print(s[0:11])
# Out:
# 12
# Hello Pytho

# %%
#9. Given a string, print characters from index 1 to index 4 using slicing.
s = 'Hello Python'
print(s[1:5])
# Out:
# ello

# %%
#10. Given a string, print characters from index 2 to index 5 using slicing.
s = 'Hello Python'
print(s[2:6])
# Out:
# llo

# %%
#11. Take a string and print characters from index 3 to the end using slicing.
s = 'Hello Python'
print(s[3:12])
# Out:
# lo Python

# %%
#12. Take a string and print characters from the start till index 4 using slicing.
s = 'Hello Python'
print(s[0:5])
# Out:
# Hello

# %%
#13. Given a string, print the entire string using slicing.

s = 'Hello Python'
print(s[0:12])
# Out:
# Hello Python

# %%
#14. Take a string and print every second character using slicing.
s = 'Hello Python'
print(s[0:12:2])
# Out:
# HloPto

# %%
#15. Given a string, print every third character using slicing.
s = 'Hello Python'
print(s[0:12:3])
# Out:
# HlPh

# %%
#16. Take a string and print alternate characters starting from index 1 using slicing.
s = 'Hello Python'
print(s[1:12:2])
# Out:
# el yhn

# %%
#17. Given a string, print the string in reverse using slicing.

s = 'Hello Python'
print(s[::-1])
# Out:
# nohtyP olleH

# %%
#18. Take a string and print the last four characters in reverse order using slicing.
s = 'Hello Python'
print(s[-4:][::-1])
# Out:
# noht

# %%
#19. Given a string, print characters from index 1 to index 6 with step 2 using slicing.
#18. Take a string and print the last four characters in reverse order using slicing.
s = 'Hello Python'
print(s[1:6:2])
# Out:
# el

# %%
#20. Take a string and print characters from index 0 to index 8 with step 3 using slicing.
#18. Take a string and print the last four characters in reverse order using slicing.
s = 'Hello Python'
print(s[0:8:3])
# Out:
# HlP

# %%
#21. Given a string, print characters from index -5 to the end using slicing.
s = 'Hello PythonProgramming'
print(s[-5:])
# Out:
# mming

# %%
#22. Take a string and print characters from index -4 to index -1 using slicing.
s = 'Hello PythonProgramming'
print(len(s))
print(s[-4:])
# Out:
# 23
# ming

# %%
#23. Given a string, print only the middle character using slicing.
s = 'Hello PythonProgramming'
print(len(s))
mid_index = len(s)//2
print(s[mid_index])
# Out:
# 23
# n

# %%
#24. Take a string and print the middle three characters using slicing.
s = 'Hello PythonProgramming'
print(len(s))
mid_index = len(s)//2
print(s[mid_index-1:mid_index+2])
# Out:
# 23
# onP

# %%
#25. Given a string, print the first half of the string using slicing.
s = 'Hello PythonProgramming'
print(len(s))
mid_index = len(s)//2
print(mid_index)
print(s[0:mid_index])
# Out:
# 23
# 11
# Hello Pytho

# %%
#26. Take a string and print the second half of the string using slicing.

s = 'Hello PythonProgramming'
print(len(s))
mid_index = len(s)//2
print(s[mid_index:len(s)])
# Out:
# 23
# nProgramming

# %%
#27. Given a string, remove the first character using slicing and print the result.
s = 'Hello PythonProgramming'

print(s[1:])
# Out:
# ello PythonProgramming

# %%
#28. Take a string and remove the last character using slicing and print the result.
s = 'Hello PythonProgramming'

print(s[:-2])
# Out:
# Hello PythonProgrammi

# %%
#29. Given a string, remove the first and last character using slicing and print the result.

s = 'Hello PythonProgramming'

print(s[1:-2])
# Out:
# ello PythonProgrammi

# %%
#30. Take a string and print the string without the first three characters using slicing.
s = 'Hello PythonProgramming'

print(s[3:])
# Out:
# lo PythonProgramming

# %%
#31. Given a string, print the string without the last three characters using slicing.
s = 'Hello PythonProgramming'

print(s[:-3])
# Out:
# Hello PythonProgramm

# %%
#32. Take a string and print characters from index 2 to index 8 using slicing.
s = 'Hello PythonProgramming'

print(s[2:8])
# Out:
# llo Py

# %%
#33. Given a string, print characters from index 0 to index 5 using slicing.
s = 'Hello PythonProgramming'

print(s[0:5])
# Out:
# Hello

# %%
#34. Take a string and print characters from index 5 to index 10 using slicing.
s = 'HelloPythonProgramming'

print(s[5:10])
# Out:
# Pytho

# %%
#35. Given a string, print characters from index -8 to index -3 using slicing.
s = 'Hello PythonProgramming'

print(s[-8:-3])
# Out:
# gramm

# %%
#36. Take a string and print characters from index -6 to the end using slicing.

s = 'HelloPythonProgramming'

print(s[-6:])
# Out:
# amming

# %%
#37. Given a string, print characters from the start till index -2 using slicing
s = 'HelloPythonProgramming'

print(s[0:-2])
# Out:
# HelloPythonProgrammi

# %%
#38. Take a string and print every second character in reverse using slicing.
s = 'HelloPythonProgramming'

print(s[0:len(s):2][::-1])
# Out:
# nmagrnhyolH

# %%
#39. Given a string, print every third character in reverse using slicing.
s = 'HelloPythonProgramming'

print(s[0:len(s):3][::-1])
# Out:
# gmrroylH

# %%
#40. Take a string and print the first five characters in reverse using slicing.
s = 'HelloPythonProgramming'

print(s[0:5][::-1])
# Out:
# olleH

# %%
#41. Given a string, print the last five characters using slicing.
s = 'HelloPythonProgramming'

print(s[-5:][::-1])
# Out:
# gnimm

# %%
#42. Take a string and print characters from index 1 to index 7 using slicing.
s = 'HelloPythonProgramming'

print(s[1:7])
# Out:
# elloPy

# %%
#43. Given a string, print characters from index 4 to index 9 using slicing.
s = 'HelloPythonProgramming'

print(s[4:9])
# Out:
# oPyth

# %%
#44. Take a string and print characters from index 2 to index -2 using slicing.
s = 'HelloPythonProgramming'

print(s[2:-2])
# Out:
# lloPythonProgrammi

# %%
#45. Given a string, print characters from index -7 to index -2 using slicing.
s = 'HelloPythonProgramming'

print(s[-7:-2])
# Out:
# rammi

# %%
#46. Take a string and print alternate characters till the middle using slicing.
s = 'HelloPythonProgramming'
mid_value = len(s)//2
print(s[0:mid_value:2])
# Out:
# Hloyhn

# %%
#47. Given a string, print alternate characters from the middle to the end using slicing.
s = 'HelloPythonProgramming'
mid_value = len(s)//2
print(s[mid_value:len(s):2])
# Out:
# Pormig

# %%
#48. Take a string and print the complete string except the middle character using slicing.
s = 'HelloPythonProgramming'
mid_value = len(s)//2
print(s[0:mid_value] + s[mid_value+1:len(s)])
# Out:
# HelloPythonrogramming

# %%
#49. Given a string, print the string starting from the second last character till the start using slicing.

s = 'HelloPythonProgramming'
print(s[:-2][::-1])
# Out:
# immargorPnohtyPolleH

# %%
#50. Take a string and print characters from index -1 to -len(string) using slicing.#48. Take a string and print the complete string except the middle character using slicing.
s = 'HelloPythonProgramming'
mid_value = len(s)//2
s1 = s[0:mid_value]+s[mid_value+1:len(s)]
print(s1)
print(s1[::-1])
# Out:
# HelloPythonrogramming
# gnimmargornohtyPolleH
