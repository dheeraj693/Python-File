# %% [markdown]
# ## Single For Loop – Level Up Questions

# %%
#1. Print numbers from 1 to 100 that are divisible by both 3 and 5.

# %%
# 2. Print numbers from 1 to 50 whose last digit is 7.

# %%
#3. Print numbers between 1 and 100 that have exactly two digits.

# %%
#4. Print the sum of squares of numbers from 1 to 10.

# %%
#5. Print the difference between the sum of even and odd numbers from 1 to 20.

# %%
#6. Print numbers from 1 to 50 that are perfect squares.

# %%
#7. Print all numbers between 1 and 100 that are divisible by 6 but not by 12.

# %%
#8. Print the count of numbers divisible by 7 between 1 and 100.

# %%
#9. Print numbers from 1 to 100 that are palindromes (single loop).

# %%
# 10. Print the product of numbers from 1 to 5 using a for loop.

# %%
#11. Print numbers from 1 to 100 whose sum of digits is 5.

# %%
#12. Print the largest number divisible by 9 between 1 and 100.

# %%
# 13. Print numbers from 1 to 50 that are divisible by 3 or 7 but not both.

# %%
# 14. Print numbers from 1 to 100 that contain the digit 3.
